# %% [markdown]
# # Introduction to `tidyverse` Round 2
# An ["opinionated" collection of R packages](https://tidyverse.org) for data science, driven by a coherent underlying design philosophy.
# These packages are meant to help you with two essential processes:
# 1. **Data clean-up and organization**: Structure should be intuitive, so that it's easy to model, manipulate, and think about the data
# 2. **Data plotting**: The grammar of graphics (Week 13)

# %%
library(tidyverse)
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.5
# v forcats   1.0.0     v stringr   1.5.2
# v ggplot2   3.5.2     v tibble    3.3.0
# v lubridate 1.9.4     v tidyr     1.3.1
# v purrr     1.1.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Loading the data

# %%
data <- read_csv("data/148338_220209_095045_M057814.csv", skip=2)
colnames(data)
# Out:
# Rows: 241 Columns: 32
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (21): type, stim1, stim2, stimPos, stimFormat, feedbackIncorrect, head, ...
# dbl (11): rowNo, ITI, feedbackTime, random, ITI_ms, ITI_f, ITI_fDuration, ti...
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#  [1] "rowNo"             "type"              "stim1"
#  [4] "stim2"             "stimPos"           "ITI"
#  [7] "stimFormat"        "feedbackIncorrect" "feedbackTime"
# [10] "head"              "responseType"      "responseOptions"
# [13] "if"                "then"              "fixation"
# [16] "button1"           "keyboard"          "key"
# [19] "cursor"            "random"            "trialType"
# [22] "correctSide"       "task"              "stimPos_actual"
# [25] "ITI_ms"            "ITI_f"             "ITI_fDuration"
# [28] "timestamp"         "response"          "RT"
# [31] "correct"           "responseCode"

# %%
education_level <- data %>% pull(response) %>% first()  

data <- data %>%
    # Keep only useful columns
    select(c(rowNo, type, stim1, stim2, stimPos, trialType, response, RT)) %>%
    
    # Keep only useful rows
    filter(type != "form") %>%
    
    # Add demographic and trial-number info, turn trial type to factor
    mutate(
        education_level = education_level, # Add info
        trial_number = row_number(),
        trialType = factor(trialType, levels = c("incongruent", "congruent"))
    ) %>%
    
    # Rename trialType to trial_type
    rename(trial_type = trialType)

head(data)
# Out:
#   rowNo type stim1          stim2          stimPos       trial_type  response
# 1 190   test croissantLarge breadSmall     -341 0; 341 0 incongruent j
# 2 125   test lampSmall      shelfLarge     -235 0; 235 0 congruent   f
# 3 200   test schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j
# 4 152   test orangeLarge    raspberrySmall -307 0; 307 0 congruent   j
# 5 110   test hammerLarge    ladderSmall    -156 0; 156 0 incongruent j
# 6 215   test wheelSmall     coinLarge      -300 0; 300 0 incongruent f
#   RT   education_level             trial_number
# 1  729 College or Technical School 1
# 2  625 College or Technical School 2
# 3 1477 College or Technical School 3
# 4  793 College or Technical School 4
# 5  900 College or Technical School 5
# 6  699 College or Technical School 6

# %% [markdown]
# ### Tidying the data

# %% [markdown]
# Our data is almost tidy, but we still need to do several things.

# %% [markdown]
# #### Exercise 1
# There are two columns that are uninformative. Remove them.

# %%
data <- data %>%
    select(-c(rowNo, type))
head(data)
# Out:
#   stim1          stim2          stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number
# 1 College or Technical School 1
# 2 College or Technical School 2
# 3 College or Technical School 3
# 4 College or Technical School 4
# 5 College or Technical School 5
# 6 College or Technical School 6

# %% [markdown]
# #### Exercise 2
# The columns `stim1` and `stim2` refer to the stimulus presented on the left and, respectively, right. Rename the columns to make them more informative.

# %%
data <- data %>%
    rename(left_stim = stim1,
        right_stim = stim2)
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number
# 1 College or Technical School 1
# 2 College or Technical School 2
# 3 College or Technical School 3
# 4 College or Technical School 4
# 5 College or Technical School 5
# 6 College or Technical School 6

# %% [markdown]
# #### Exercise 3
# Add a new column called `subject_id` and set this participant to 1.

# %%
data <- data %>%
    mutate(subject_id = 1)
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id
# 1 College or Technical School 1            1
# 2 College or Technical School 2            1
# 3 College or Technical School 3            1
# 4 College or Technical School 4            1
# 5 College or Technical School 5            1
# 6 College or Technical School 6            1

# %% [markdown]
# #### Exercise 4
# Add a new column called `correct_side`. This column should encode the side of the correct answer (equivalently, the side of the smaller image). Use `str_detect(string, pattern)` to compute where the smaller image was on the screen and use a conditional `mutate` to fill in the values of `correct_side`.

# %%
data <- data %>%
    mutate(correct_side = ifelse(str_detect(right_stim, 'Small'), 'right', 'left'))
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side
# 1 College or Technical School 1            1          right
# 2 College or Technical School 2            1          left
# 3 College or Technical School 3            1          right
# 4 College or Technical School 4            1          right
# 5 College or Technical School 5            1          right
# 6 College or Technical School 6            1          left

# %% [markdown]
# #### Exercise 5
# Add a new column called `correct_key`. This column should be equal to `f` if the smaller image was on the left, and to `j` if the smaller image was on the right.

# %%
data <- data %>%
    mutate(correct_key = ifelse(correct_side == 'left', 'f', 'j'))
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f

# %% [markdown]
# #### Exercise 6
# Add a new column called `correct`. This column should be equal to 1 if the participant provided a correct response, 0 otherwise.

# %%
data <- data %>%
    mutate(correct = ifelse(response == correct_key, 1, 0))
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f
#   correct
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %% [markdown]
# #### Exercise 7
# The experiment had 240 trials, equally divided into two blocks. Add a new column called `trial_block` that encodes this.

# %%
data <- data %>%
    mutate(trial_block = ifelse(trial_number <= 120, 1, 2))
head(data)
# Out:
#   left_stim      right_stim     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f
#   correct trial_block
# 1 1       1
# 2 1       1
# 3 1       1
# 4 1       1
# 5 1       1
# 6 1       1

# %% [markdown]
# #### Exercise 8
# Recode `trial_number` so that it codes the trial number within a block. Instead of going from 1 to 240, it should go from 1 to 120 twice.

# %%
data <- data %>%
    mutate(trial_number = ifelse(trial_block == 2 & trial_number > 120, trial_number - 120, trial_number))
data
# Out:
#     left_stim        right_stim      stimPos       trial_type  response RT
# 1   croissantLarge   breadSmall      -341 0; 341 0 incongruent j         729
# 2   lampSmall        shelfLarge      -235 0; 235 0 congruent   f         625
# 3   schoolbusLarge   bikeSmall       -370 0; 370 0 congruent   j        1477
# 4   orangeLarge      raspberrySmall  -307 0; 307 0 congruent   j         793
# 5   hammerLarge      ladderSmall     -156 0; 156 0 incongruent j         900
# 6   wheelSmall       coinLarge       -300 0; 300 0 incongruent f         699
# 7   coconutSmall     blueberryLarge  -309 0; 309 0 incongruent f         752
# 8   pumpkinLarge     mushroomSmall   -304 0; 304 0 congruent   j         567
# 9   croissantSmall   breadLarge      -341 0; 341 0 congruent   f         556
# 10  trayLarge        bedSmall        -350 0; 350 0 incongruent j         801
# 11  lettuceLarge     oliveSmall      -365 0; 365 0 congruent   j         564
# 12  cornSmall        green beanLarge -349 0; 349 0 incongruent f         597
# 13  chilliSmall      eggplantLarge   -274 0; 274 0 congruent   f         534
# 14  kittySmall       donkeyLarge     -309 0; 309 0 congruent   f         436
# 15  apricotLarge     watermelonSmall -300 0; 300 0 incongruent j         457
# 16  cowSmall         hedgehogLarge   -358 0; 358 0 incongruent f         481
# 17  cauliflowerSmall onionLarge      -321 0; 321 0 incongruent f         480
# 18  duckSmall        zebraLarge      -311 0; 311 0 congruent   f         426
# 19  wheelbarrowSmall carLarge        -347 0; 347 0 congruent   f         437
# 20  dishwasherLarge  backpackSmall   -259 0; 259 0 congruent   j         606
# 21  chickenSmall     pandaLarge      -333 0; 333 0 congruent   f         460
# 22  parrotSmall      orangutanLarge  -207 0; 207 0 congruent   f         454
# 23  airplaneLarge    skateboardSmall -334 0; 334 0 congruent   j         614
# 24  deerSmall        frogLarge       -299 0; 299 0 incongruent f         490
# 25  giraffeSmall     antLarge        -324 0; 324 0 incongruent f        1037
# 26  dolphinSmall     goldfishLarge   -341 0; 341 0 incongruent f         485
# 27  tableLarge       hairdryerSmall  -350 0; 350 0 congruent   j         493
# 28  beeSmall         sheepLarge      -321 0; 321 0 congruent   f         428
# 29  graterSmall      skyscraperLarge -220 0; 220 0 congruent   f         501
# 30  donkeySmall      kittyLarge      -317 0; 317 0 incongruent f         990
# ... ...              ...             ...           ...         ...      ...
# 211 orangutanSmall   parrotLarge     -198 0; 198 0 incongruent f         808
# 212 pigeonLarge      camelSmall      -250 0; 250 0 incongruent j         957
# 213 squirrelSmall    gorillaLarge    -306 0; 306 0 congruent   f         540
# 214 pineappleSmall   cherryLarge     -223 0; 223 0 incongruent f         404
# 215 lighterLarge     treeSmall       -192 0; 192 0 incongruent j         586
# 216 alligatorLarge   shrimpSmall     -337 0; 337 0 congruent   j         560
# 217 beltLarge        cannonSmall     -353 0; 353 0 incongruent j        1199
# 218 ovenSmall        bootLarge       -280 0; 280 0 incongruent f         478
# 219 oliveLarge       lettuceSmall    -363 0; 363 0 incongruent j        1407
# 220 treeLarge        lighterSmall    -208 0; 208 0 congruent   j         547
# 221 cannonLarge      beltSmall       -353 0; 353 0 congruent   j         522
# 222 ovenLarge        bootSmall       -273 0; 273 0 congruent   j         498
# 223 sheepLarge       beeSmall        -321 0; 321 0 congruent   j         490
# 224 backpackSmall    dishwasherLarge -259 0; 259 0 congruent   f         437
# 225 scissorsLarge    trunkSmall      -198 0; 198 0 incongruent j         727
# 226 cannonSmall      beltLarge       -353 0; 353 0 incongruent f         523
# 227 plumSmall        melonLarge      -330 0; 330 0 congruent   f         447
# 228 lettuceSmall     oliveLarge      -363 0; 363 0 incongruent f         416
# 229 tigerSmall       rabbitLarge     -306 0; 306 0 incongruent f         455
# 230 houseLarge       leafSmall       -337 0; 337 0 incongruent j         518
# 231 lizardSmall      rhinoLarge      -369 0; 369 0 congruent   f         458
# 232 butterflySmall   elephantLarge   -322 0; 322 0 congruent   f         433
# 233 treeSmall        lighterLarge    -192 0; 192 0 incongruent f         429
# 234 elephantLarge    butterflySmall  -322 0; 322 0 congruent   j         476
# 235 gorillaSmall     squirrelLarge   -306 0; 306 0 incongruent f         456
# 236 schoolbusSmall   bikeLarge       -366 0; 366 0 incongruent f         672
# 237 orangeSmall      raspberryLarge  -308 0; 308 0 incongruent f         357
# 238 helicopterLarge  tricycleSmall   -353 0; 353 0 congruent   j         498
# 239 scissorsSmall    trunkLarge      -215 0; 215 0 congruent   f         697
# 240 oliveSmall       lettuceLarge    -365 0; 365 0 congruent   f         414
#     education_level             trial_number subject_id correct_side
# 1   College or Technical School  1           1          right
# 2   College or Technical School  2           1          left
# 3   College or Technical School  3           1          right
# 4   College or Technical School  4           1          right
# 5   College or Technical School  5           1          right
# 6   College or Technical School  6           1          left
# 7   College or Technical School  7           1          left
# 8   College or Technical School  8           1          right
# 9   College or Technical School  9           1          left
# 10  College or Technical School 10           1          right
# 11  College or Technical School 11           1          right
# 12  College or Technical School 12           1          left
# 13  College or Technical School 13           1          left
# 14  College or Technical School 14           1          left
# 15  College or Technical School 15           1          right
# 16  College or Technical School 16           1          left
# 17  College or Technical School 17           1          left
# 18  College or Technical School 18           1          left
# 19  College or Technical School 19           1          left
# 20  College or Technical School 20           1          right
# 21  College or Technical School 21           1          left
# 22  College or Technical School 22           1          left
# 23  College or Technical School 23           1          right
# 24  College or Technical School 24           1          left
# 25  College or Technical School 25           1          left
# 26  College or Technical School 26           1          left
# 27  College or Technical School 27           1          right
# 28  College or Technical School 28           1          left
# 29  College or Technical School 29           1          left
# 30  College or Technical School 30           1          left
# ... ...                         ...          ...        ...
# 211 College or Technical School  91          1          left
# 212 College or Technical School  92          1          right
# 213 College or Technical School  93          1          left
# 214 College or Technical School  94          1          left
# 215 College or Technical School  95          1          right
# 216 College or Technical School  96          1          right
# 217 College or Technical School  97          1          right
# 218 College or Technical School  98          1          left
# 219 College or Technical School  99          1          right
# 220 College or Technical School 100          1          right
# 221 College or Technical School 101          1          right
# 222 College or Technical School 102          1          right
# 223 College or Technical School 103          1          right
# 224 College or Technical School 104          1          left
# 225 College or Technical School 105          1          right
# 226 College or Technical School 106          1          left
# 227 College or Technical School 107          1          left
# 228 College or Technical School 108          1          left
# 229 College or Technical School 109          1          left
# 230 College or Technical School 110          1          right
# 231 College or Technical School 111          1          left
# 232 College or Technical School 112          1          left
# 233 College or Technical School 113          1          left
# 234 College or Technical School 114          1          right
# 235 College or Technical School 115          1          left
# 236 College or Technical School 116          1          left
# 237 College or Technical School 117          1          left
# 238 College or Technical School 118          1          right
# 239 College or Technical School 119          1          left
# 240 College or Technical School 120          1          left
#     correct_key correct trial_block
# 1   j           1       1
# 2   f           1       1
# 3   j           1       1
# 4   j           1       1
# 5   j           1       1
# 6   f           1       1
# 7   f           1       1
# 8   j           1       1
# 9   f           1       1
# 10  j           1       1
# 11  j           1       1
# 12  f           1       1
# 13  f           1       1
# 14  f           1       1
# 15  j           1       1
# 16  f           1       1
# 17  f           1       1
# 18  f           1       1
# 19  f           1       1
# 20  j           1       1
# 21  f           1       1
# 22  f           1       1
# 23  j           1       1
# 24  f           1       1
# 25  f           1       1
# 26  f           1       1
# 27  j           1       1
# 28  f           1       1
# 29  f           1       1
# 30  f           1       1
# ... ...         ...     ...
# 211 f           1       2
# 212 j           1       2
# 213 f           1       2
# 214 f           1       2
# 215 j           1       2
# 216 j           1       2
# 217 j           1       2
# 218 f           1       2
# 219 j           1       2
# 220 j           1       2
# 221 j           1       2
# 222 j           1       2
# 223 j           1       2
# 224 f           1       2
# 225 j           1       2
# 226 f           1       2
# 227 f           1       2
# 228 f           1       2
# 229 f           1       2
# 230 j           1       2
# 231 f           1       2
# 232 f           1       2
# 233 f           1       2
# 234 j           1       2
# 235 f           1       2
# 236 f           1       2
# 237 f           1       2
# 238 j           1       2
# 239 f           1       2
# 240 f           1       2

# %% [markdown]
# #### Exercise 9
# It is good practice to use a consistent style throughout your script. One such style is called **snake**, the standard in python, which uses only lowercase letters and underscores: `variable_name`. Another common style is **camel**, the standard in JavaScript, which uses capital letters to mark the beginning of a new word: `variableName`. Our tibble at this point uses both styles, so turn all variable names to snake case. You can use `colnames` to see the vector of column names.

# %%
data <- data %>%
    rename(stim_pos = stimPos, rt = RT)
colnames(data)
# Out:
#  [1] "left_stim"       "right_stim"      "stim_pos"        "trial_type"
#  [5] "response"        "rt"              "education_level" "trial_number"
#  [9] "subject_id"      "correct_side"    "correct_key"     "correct"
# [13] "trial_block"

# %% [markdown]
# #### Exercise 10
# Using `select`, reorder the columns such that participant information comes first, followed by trial block and number, followed by trial info.

# %%
data %>% colnames()
data <- data %>%
    select(c(subject_id, education_level, trial_block, trial_number, left_stim, right_stim, stim_pos, trial_type, correct_side, correct_key, response, correct, rt))
data %>% colnames()
# Out:
#  [1] "left_stim"       "right_stim"      "stim_pos"        "trial_type"
#  [5] "response"        "rt"              "education_level" "trial_number"
#  [9] "subject_id"      "correct_side"    "correct_key"     "correct"
# [13] "trial_block"
#  [1] "subject_id"      "education_level" "trial_block"     "trial_number"
#  [5] "left_stim"       "right_stim"      "stim_pos"        "trial_type"
#  [9] "correct_side"    "correct_key"     "response"        "correct"
# [13] "rt"

# %% [markdown]
# #### Exercise 11
# Concatenate all the commands in Exercises 1–10 into a single cell and store the output in a variable called `tidy_data`.

# %%
tidy_data <- data %>%
    select(-c(rowNo, type)) %>%
    rename(left_stim = stim1, right_stim = stim2) %>%
    mutate(subject_id = 1, 
        correct_side = ifelse(str_detect(right_stim, 'Small'), 'right', 'left'),
        correct_key = ifelse(correct_side == 'left', 'f', 'j'),
        correct = ifelse(response == correct_key, 1, 0),
        trial_block = ifelse(trial_number <= 120, 1, 2),
        trial_number = ifelse(trial_block == 2 & trial_number > 120, trial_number - 120, trial_number)) %>%
    rename(stim_pos = stimPos, rt = RT) %>%
    select(c(subject_id, education_level, trial_block, trial_number, left_stim, right_stim, stim_pos, 
        trial_type, correct_side, correct_key, response, correct, rt))
head(tidy_data)
# Out:
#   subject_id education_level             trial_block trial_number
# 1 1          College or Technical School 1           1
# 2 1          College or Technical School 1           2
# 3 1          College or Technical School 1           3
# 4 1          College or Technical School 1           4
# 5 1          College or Technical School 1           5
# 6 1          College or Technical School 1           6
#   left_stim      right_stim     stim_pos      trial_type  correct_side
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent right
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   left
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   right
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   right
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent right
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent left
#   correct_key response correct rt
# 1 j           j        1        729
# 2 f           f        1        625
# 3 j           j        1       1477
# 4 j           j        1        793
# 5 j           j        1        900
# 6 f           f        1        699

# %% [markdown]
# ### Summary statistics

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct))
# Out:
#   rt       accuracy  error
# 1 622.7542 0.9833333 0.01666667

# %%
tidy_data %>%
    mutate(avg_error = mean(1 - correct))
# Out:
#     subject_id education_level             trial_block trial_number
# 1   1          College or Technical School 1            1
# 2   1          College or Technical School 1            2
# 3   1          College or Technical School 1            3
# 4   1          College or Technical School 1            4
# 5   1          College or Technical School 1            5
# 6   1          College or Technical School 1            6
# 7   1          College or Technical School 1            7
# 8   1          College or Technical School 1            8
# 9   1          College or Technical School 1            9
# 10  1          College or Technical School 1           10
# 11  1          College or Technical School 1           11
# 12  1          College or Technical School 1           12
# 13  1          College or Technical School 1           13
# 14  1          College or Technical School 1           14
# 15  1          College or Technical School 1           15
# 16  1          College or Technical School 1           16
# 17  1          College or Technical School 1           17
# 18  1          College or Technical School 1           18
# 19  1          College or Technical School 1           19
# 20  1          College or Technical School 1           20
# 21  1          College or Technical School 1           21
# 22  1          College or Technical School 1           22
# 23  1          College or Technical School 1           23
# 24  1          College or Technical School 1           24
# 25  1          College or Technical School 1           25
# 26  1          College or Technical School 1           26
# 27  1          College or Technical School 1           27
# 28  1          College or Technical School 1           28
# 29  1          College or Technical School 1           29
# 30  1          College or Technical School 1           30
# ... ...        ...                         ...         ...
# 211 1          College or Technical School 2            91
# 212 1          College or Technical School 2            92
# 213 1          College or Technical School 2            93
# 214 1          College or Technical School 2            94
# 215 1          College or Technical School 2            95
# 216 1          College or Technical School 2            96
# 217 1          College or Technical School 2            97
# 218 1          College or Technical School 2            98
# 219 1          College or Technical School 2            99
# 220 1          College or Technical School 2           100
# 221 1          College or Technical School 2           101
# 222 1          College or Technical School 2           102
# 223 1          College or Technical School 2           103
# 224 1          College or Technical School 2           104
# 225 1          College or Technical School 2           105
# 226 1          College or Technical School 2           106
# 227 1          College or Technical School 2           107
# 228 1          College or Technical School 2           108
# 229 1          College or Technical School 2           109
# 230 1          College or Technical School 2           110
# 231 1          College or Technical School 2           111
# 232 1          College or Technical School 2           112
# 233 1          College or Technical School 2           113
# 234 1          College or Technical School 2           114
# 235 1          College or Technical School 2           115
# 236 1          College or Technical School 2           116
# 237 1          College or Technical School 2           117
# 238 1          College or Technical School 2           118
# 239 1          College or Technical School 2           119
# 240 1          College or Technical School 2           120
#     left_stim        right_stim      stim_pos      trial_type  correct_side
# 1   croissantLarge   breadSmall      -341 0; 341 0 incongruent right
# 2   lampSmall        shelfLarge      -235 0; 235 0 congruent   left
# 3   schoolbusLarge   bikeSmall       -370 0; 370 0 congruent   right
# 4   orangeLarge      raspberrySmall  -307 0; 307 0 congruent   right
# 5   hammerLarge      ladderSmall     -156 0; 156 0 incongruent right
# 6   wheelSmall       coinLarge       -300 0; 300 0 incongruent left
# 7   coconutSmall     blueberryLarge  -309 0; 309 0 incongruent left
# 8   pumpkinLarge     mushroomSmall   -304 0; 304 0 congruent   right
# 9   croissantSmall   breadLarge      -341 0; 341 0 congruent   left
# 10  trayLarge        bedSmall        -350 0; 350 0 incongruent right
# 11  lettuceLarge     oliveSmall      -365 0; 365 0 congruent   right
# 12  cornSmall        green beanLarge -349 0; 349 0 incongruent left
# 13  chilliSmall      eggplantLarge   -274 0; 274 0 congruent   left
# 14  kittySmall       donkeyLarge     -309 0; 309 0 congruent   left
# 15  apricotLarge     watermelonSmall -300 0; 300 0 incongruent right
# 16  cowSmall         hedgehogLarge   -358 0; 358 0 incongruent left
# 17  cauliflowerSmall onionLarge      -321 0; 321 0 incongruent left
# 18  duckSmall        zebraLarge      -311 0; 311 0 congruent   left
# 19  wheelbarrowSmall carLarge        -347 0; 347 0 congruent   left
# 20  dishwasherLarge  backpackSmall   -259 0; 259 0 congruent   right
# 21  chickenSmall     pandaLarge      -333 0; 333 0 congruent   left
# 22  parrotSmall      orangutanLarge  -207 0; 207 0 congruent   left
# 23  airplaneLarge    skateboardSmall -334 0; 334 0 congruent   right
# 24  deerSmall        frogLarge       -299 0; 299 0 incongruent left
# 25  giraffeSmall     antLarge        -324 0; 324 0 incongruent left
# 26  dolphinSmall     goldfishLarge   -341 0; 341 0 incongruent left
# 27  tableLarge       hairdryerSmall  -350 0; 350 0 congruent   right
# 28  beeSmall         sheepLarge      -321 0; 321 0 congruent   left
# 29  graterSmall      skyscraperLarge -220 0; 220 0 congruent   left
# 30  donkeySmall      kittyLarge      -317 0; 317 0 incongruent left
# ... ...              ...             ...           ...         ...
# 211 orangutanSmall   parrotLarge     -198 0; 198 0 incongruent left
# 212 pigeonLarge      camelSmall      -250 0; 250 0 incongruent right
# 213 squirrelSmall    gorillaLarge    -306 0; 306 0 congruent   left
# 214 pineappleSmall   cherryLarge     -223 0; 223 0 incongruent left
# 215 lighterLarge     treeSmall       -192 0; 192 0 incongruent right
# 216 alligatorLarge   shrimpSmall     -337 0; 337 0 congruent   right
# 217 beltLarge        cannonSmall     -353 0; 353 0 incongruent right
# 218 ovenSmall        bootLarge       -280 0; 280 0 incongruent left
# 219 oliveLarge       lettuceSmall    -363 0; 363 0 incongruent right
# 220 treeLarge        lighterSmall    -208 0; 208 0 congruent   right
# 221 cannonLarge      beltSmall       -353 0; 353 0 congruent   right
# 222 ovenLarge        bootSmall       -273 0; 273 0 congruent   right
# 223 sheepLarge       beeSmall        -321 0; 321 0 congruent   right
# 224 backpackSmall    dishwasherLarge -259 0; 259 0 congruent   left
# 225 scissorsLarge    trunkSmall      -198 0; 198 0 incongruent right
# 226 cannonSmall      beltLarge       -353 0; 353 0 incongruent left
# 227 plumSmall        melonLarge      -330 0; 330 0 congruent   left
# 228 lettuceSmall     oliveLarge      -363 0; 363 0 incongruent left
# 229 tigerSmall       rabbitLarge     -306 0; 306 0 incongruent left
# 230 houseLarge       leafSmall       -337 0; 337 0 incongruent right
# 231 lizardSmall      rhinoLarge      -369 0; 369 0 congruent   left
# 232 butterflySmall   elephantLarge   -322 0; 322 0 congruent   left
# 233 treeSmall        lighterLarge    -192 0; 192 0 incongruent left
# 234 elephantLarge    butterflySmall  -322 0; 322 0 congruent   right
# 235 gorillaSmall     squirrelLarge   -306 0; 306 0 incongruent left
# 236 schoolbusSmall   bikeLarge       -366 0; 366 0 incongruent left
# 237 orangeSmall      raspberryLarge  -308 0; 308 0 incongruent left
# 238 helicopterLarge  tricycleSmall   -353 0; 353 0 congruent   right
# 239 scissorsSmall    trunkLarge      -215 0; 215 0 congruent   left
# 240 oliveSmall       lettuceLarge    -365 0; 365 0 congruent   left
#     correct_key response correct rt   avg_error
# 1   j           j        1        729 0.01666667
# 2   f           f        1        625 0.01666667
# 3   j           j        1       1477 0.01666667
# 4   j           j        1        793 0.01666667
# 5   j           j        1        900 0.01666667
# 6   f           f        1        699 0.01666667
# 7   f           f        1        752 0.01666667
# 8   j           j        1        567 0.01666667
# 9   f           f        1        556 0.01666667
# 10  j           j        1        801 0.01666667
# 11  j           j        1        564 0.01666667
# 12  f           f        1        597 0.01666667
# 13  f           f        1        534 0.01666667
# 14  f           f        1        436 0.01666667
# 15  j           j        1        457 0.01666667
# 16  f           f        1        481 0.01666667
# 17  f           f        1        480 0.01666667
# 18  f           f        1        426 0.01666667
# 19  f           f        1        437 0.01666667
# 20  j           j        1        606 0.01666667
# 21  f           f        1        460 0.01666667
# 22  f           f        1        454 0.01666667
# 23  j           j        1        614 0.01666667
# 24  f           f        1        490 0.01666667
# 25  f           f        1       1037 0.01666667
# 26  f           f        1        485 0.01666667
# 27  j           j        1        493 0.01666667
# 28  f           f        1        428 0.01666667
# 29  f           f        1        501 0.01666667
# 30  f           f        1        990 0.01666667
# ... ...         ...      ...     ...  ...
# 211 f           f        1        808 0.01666667
# 212 j           j        1        957 0.01666667
# 213 f           f        1        540 0.01666667
# 214 f           f        1        404 0.01666667
# 215 j           j        1        586 0.01666667
# 216 j           j        1        560 0.01666667
# 217 j           j        1       1199 0.01666667
# 218 f           f        1        478 0.01666667
# 219 j           j        1       1407 0.01666667
# 220 j           j        1        547 0.01666667
# 221 j           j        1        522 0.01666667
# 222 j           j        1        498 0.01666667
# 223 j           j        1        490 0.01666667
# 224 f           f        1        437 0.01666667
# 225 j           j        1        727 0.01666667
# 226 f           f        1        523 0.01666667
# 227 f           f        1        447 0.01666667
# 228 f           f        1        416 0.01666667
# 229 f           f        1        455 0.01666667
# 230 j           j        1        518 0.01666667
# 231 f           f        1        458 0.01666667
# 232 f           f        1        433 0.01666667
# 233 f           f        1        429 0.01666667
# 234 j           j        1        476 0.01666667
# 235 f           f        1        456 0.01666667
# 236 f           f        1        672 0.01666667
# 237 f           f        1        357 0.01666667
# 238 j           j        1        498 0.01666667
# 239 f           f        1        697 0.01666667
# 240 f           f        1        414 0.01666667

# %% [markdown]
# #### Exercise 12
# Using the `.by` argument in the call to `summarize`, find out if our participant showed the predicted size Stroop in reaction times and error rates.

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct), .by = trial_type)
# Out:
#   trial_type  rt       accuracy  error
# 1 incongruent 698.1000 0.9666667 0.03333333
# 2 congruent   547.4083 1.0000000 0.00000000

# %% [markdown]
# #### Exercise 13
# Using a similar logic, find out if our participant also showed a SNARC effect: Was the participant faster when the small image was on the left?

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct), .by = correct_side)
# Out:
#   correct_side rt       accuracy  error
# 1 right        632.7333 0.9750000 0.025000000
# 2 left         612.7750 0.9916667 0.008333333

# %% [markdown]
# #### Exercise 14
# Find out if the SNARC effect depends on trial type.

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct), .by = c(trial_type, correct_side))
# Out:
#   trial_type  correct_side rt       accuracy  error
# 1 incongruent right        694.9167 0.9500000 0.05000000
# 2 congruent   left         524.2667 1.0000000 0.00000000
# 3 congruent   right        570.5500 1.0000000 0.00000000
# 4 incongruent left         701.2833 0.9833333 0.01666667

# %% [markdown]
# ## From a single participant to a full dataset
# We load all the 12 csv files in the 'data' folder, then apply the `read_csv` function to each of them using `map_dfr`. The `.id` argument creates a column that keeps the information from each file separate. This is equivalent to having a subject_id, if there is one .csv file per participant.

# %%
# Fetch all the files in the 'data' folder that end in .csv
raw_data <- list.files(path = 'data', pattern = ".csv$", full.names = TRUE) %>% 

  # Map the read_csv function to all of them, skipping the first 2 rows and creating a new id column called 'id' so that each file gets its own id
  # col_types = cols() just makes explicit that you want tidyverse to do its best to guess the type of each column (string, numeric, etc.)
  map_dfr(read_csv, col_types = cols(), skip = 2, .id = 'id')

# %% [markdown]
# #### Exercise 15
# Tidy the dataset exactly as we did for subject 1, while keeping the education-level information for each subject. Store it as `tidy_data`.
#
# Hint: **group** the tibble before calling `first(response)`), then follow the same steps as before to obtain a tidy dataset. Use `ungroup()` to return to the tibble to the ungrouped state. In fact, in most of the exercises that follow, you will need to use grouping wisely.
#
# ```R
# full_data <- raw_data %>%
#     mutate(education_level = first(response), .by = id) %>%
#     ...
# ```

# %%
full_data <- raw_data %>%
    mutate(education_level = first(response), .by = id) %>%
    filter(type != "form") %>%
    select(-c(rowNo, type)) %>%
    rename(left_stim = stim1, right_stim = stim2, subject_id = id, stim_pos = stimPos, rt = RT) %>%
    mutate(trial_number = row_number(), .by = subject_id) %>%
    mutate(
        correct_side = ifelse(str_detect(right_stim, 'Small'), 'right', 'left'),
        correct_key = ifelse(correct_side == 'left', 'f', 'j'),
        correct = ifelse(response == correct_key, 1, 0),
        trial_block = ifelse(trial_number <= 120, 1, 2),
        trial_type = factor(trialType, levels = c("incongruent", "congruent")),
        trial_number = ifelse(trial_block == 2 & trial_number > 120, trial_number - 120, trial_number)) %>%
    select(c(subject_id, education_level, trial_block, trial_number, left_stim, right_stim, stim_pos, 
        trial_type, correct_side, correct_key, response, correct, rt))
head(full_data)
# Out:
#   subject_id education_level             trial_block trial_number
# 1 1          College or Technical School 1           1
# 2 1          College or Technical School 1           2
# 3 1          College or Technical School 1           3
# 4 1          College or Technical School 1           4
# 5 1          College or Technical School 1           5
# 6 1          College or Technical School 1           6
#   left_stim      right_stim     stim_pos      trial_type  correct_side
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent right
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   left
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   right
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   right
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent right
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent left
#   correct_key response correct rt
# 1 j           j        1        729
# 2 f           f        1        625
# 3 j           j        1       1477
# 4 j           j        1        793
# 5 j           j        1        900
# 6 f           f        1        699

# %% [markdown]
# #### Exercise 16
# Trials where the responses were too slow or too fast should be excluded from the analysis. (Why?)
# Exclude the trials where the response is below 200 ms or higher than 1,500 ms. How many trials were excluded?

# %%
#Trials that are too slow or fast don't represent on-task reaction time
filtered_trials <- full_data %>%
    subset(rt > 200 & rt < 1500)
print(paste('# of excluded trials:', nrow(full_data)-nrow(filtered_trials)))
print(paste('% of excluded trials:', (nrow(full_data)-nrow(filtered_trials))/nrow(full_data)*100))
# Out:
# [1] "# of excluded trials: 285"
# [1] "% of excluded trials: 9.89583333333333"

# %% [markdown]
# #### Exercise 17
# Exclude participants who didn't achieve 93% overall accuracy.
# How many subjects were excluded?

# %%
filtered_id <- filtered_trials %>%
    group_by(subject_id) %>%
    mutate(mean_accuracy = mean(correct)) %>%
    subset(mean_accuracy > .93) %>%
    ungroup()
print(paste('# of excluded subjects:', n_distinct(pull(filtered_trials, subject_id))-n_distinct(pull(filtered_id, subject_id))))
print(paste('% of excluded subjects:', (n_distinct(pull(filtered_trials, subject_id))-n_distinct(pull(filtered_id, subject_id)))/n_distinct(pull(filtered_trials, subject_id))*100))
# Out:
# [1] "# of excluded subjects: 1"
# [1] "% of excluded subjects: 8.33333333333333"

# %% [markdown]
# #### Exercise 18
# Summarize the response-time and accuracy measures by trial type to check whether there's a Stroop effect.

# %%
filtered_id %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct), .by = c(trial_type))
# Out:
#   trial_type  rt      accuracy  error
# 1 incongruent 813.829 0.9352332 0.064766839
# 2 congruent   707.751 0.9941520 0.005847953

# %% [markdown]
# ## Changing the format of the data: `pivot_wider`, `pivot_longer`

# %% [markdown]
# #### Exercise 19: `pivot_wider`
# Compute the average Stroop effects for each participant. One column should be called `stroop_rt`, the other should be called `stroop_error`. Using `pull`, extract the reaction-time Stroop vector and plot its histogram.

# %%
stroop_effect <- filtered_id %>%
    group_by(subject_id, trial_type) %>%
    summarize(rt = mean(rt), error = mean(1 - correct), .groups = 'drop') %>%
    pivot_wider(names_from = trial_type, values_from = c(rt, error)) %>%
    mutate(stroop_rt = rt_incongruent - rt_congruent, stroop_error = error_incongruent - error_congruent)
stroop_effect %>%
    pull(stroop_rt) %>%
    hist()
# Out:
# Plot with title "Histogram of ."

# %% [markdown]
# #### Exercise 20: `pivot_longer`
# Building on the output tibble in Exercise 19, remove all columns except `id`, `stroop_rt`, and `stroop_error`, then gather the two stroop columns into a single column called `measure`. This column should take one of two values for each subject (`stroop_rt` or `stroop_error`), while the `value` column should register the respective participants' stroop effect.

# %% [markdown]
# ## Data plotting

# %% [markdown]
# ### Rule 1: If your data is in the tidy format (one variable per column, one observation per row), plotting with `ggplot` will be very easy.

# %% [markdown]
# ### Rule 2: No barplots.

# %% [markdown]
# ### One possible way to do it

# %%
average_data <- full_data %>% summarize(rt = mean(rt), .by = c(id, trial_type)) 

ggplot(average_data, aes(x = trial_type, y = rt, fill = trial_type)) +
  geom_boxplot(width = 0.5, alpha = 0.45) +
  geom_point(size = 2) +
  geom_line(aes(group = id), color = 'gray') +         
  stat_summary(fun.data = mean_se, linewidth = 2, shape = 21, size = 1.5) +
  labs(title = "Average reaction times by trial type (ms)", x = "Trial type", y = "") +
  theme_minimal() + 
  theme(
    legend.position = "none", 
    plot.title = element_text(face = "bold", size = 20),
    axis.title = element_text(size = 18),
    axis.text = element_text(size = 16))
